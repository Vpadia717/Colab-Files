# %% [markdown]
# # ***Name : Vivek Padia***
# # ***Enrolment : 21SOEIT13014***
# # ***Branch : 4IT***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re
quote = "A great chef is first a great technician"
word = input('Enter string : ')

print(len(re.findall(word,quote)),'items found')
# Out:
# Enter string : great
# 2 items found
