# %% [markdown]
# # ***Name : Vivek Padia***
# # ***Enrolment : 21SOEIT13014***
# # ***Branch : 4IT***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re

text = input('Enter input : ')

pattern = r"#\w+"
list1 = []
list1 = re.findall(pattern,text)
print(*list1, sep = "\n")
# Out:
# Enter input : #Covid19 is also known #Corona #virus
# #Covid19
# #Corona
# #virus
