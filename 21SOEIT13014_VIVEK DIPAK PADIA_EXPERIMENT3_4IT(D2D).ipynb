# %% [markdown]
# # ***Name : Vivek Padia***
# # ***Enrolment : 21SOEIT13014***
# # ***Branch : 4IT***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re

str = input('Enter the number : ')

pattern = r"00"
newstr = re.sub(pattern,"91",str,count=1)
print(newstr)
# Out:
# Enter the number : 0098989898
# 9198989898
