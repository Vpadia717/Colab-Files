# %% [markdown]
# # ***Name : Vivek Padia***
# # ***Enrolment : 21SOEIT13014***
# # ***Branch : 4IT***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re

pattern = r"[A-Z,a-z,@,0-9,0-9$]"

a = input('Enter the string : ')

if re.match(pattern,a):
  print("Seraching")
else:
  print('Wrong Format')
# Out:
# Enter the string : Tv@12
# Seraching
